# %%
import pandas as pd

# %%
formula_circuits = pd.read_csv('circuits.csv')
formula_circuits
# Out:
#     circuitId   circuitRef                                  name  \
# 0           1  albert_park        Albert Park Grand Prix Circuit
# 1           2       sepang          Sepang International Circuit
# 2           3      bahrain         Bahrain International Circuit
# 3           4    catalunya        Circuit de Barcelona-Catalunya
# 4           5     istanbul                         Istanbul Park
# ..        ...          ...                                   ...
# 72         75     portimao    Autódromo Internacional do Algarve
# 73         76      mugello  Autodromo Internazionale del Mugello
# 74         77       jeddah               Jeddah Corniche Circuit
# 75         78       losail          Losail International Circuit
# 76         79        miami         Miami International Autodrome
#
#         location       country       lat        lng  alt  \
# 0      Melbourne     Australia -37.84970  144.96800   10
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800   18
# ...

# %%
formula_circ_longitude = formula_circuits[formula_circuits['lng'] > -50]
formula_circ_longitude = formula_circ_longitude[['country', 'lng']]
formula_circ_longitude
# Out:
#          country         lng
# 0      Australia  144.968000
# 1       Malaysia  101.738000
# 2        Bahrain   50.510600
# 3          Spain    2.261110
# 4         Turkey   29.405000
# 5         Monaco    7.420560
# 7         France    3.163610
# 8             UK   -1.016940
# 9        Germany    8.565830
# 10       Hungary   19.248600
# 11         Spain   -0.331667
# 12       Belgium    5.971390
# 13         Italy    9.281110
# 14     Singapore  103.864000
# 15         Japan  138.927000
# 16         China  121.220000
# 17        Brazil  -46.699700
# 19       Germany    6.947500
# 20         Italy   11.716700
# 21         Japan  136.541000
# 23           UAE   54.603100
# 25         Spain   -6.034170
# 26      Portugal   -9.394170
# 27         Japan  134.221000
# 28     Australia  138.617000
# 29  South Africa   28.076700
# 30            UK   -1.375280
# 33        France    5.791670
# 34         Korea  126.417000
# 35        Brazil  -43.395000
# 37            UK    0.263056
# ...

# %%
formula_alt_range = formula_circuits[(formula_circuits['alt'] > 200) & (formula_circuits['alt'] > 800)]
formula_alt_range = formula_alt_range[['country', 'alt']]
formula_alt_range
# Out:
#          country   alt
# 29  South Africa  1460
# 31        Mexico  2227
# 35        Brazil  1126

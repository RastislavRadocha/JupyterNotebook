# %%
import pandas as pd

# %%
pokemon = pd.read_csv('Pokemon.csv', index_col='#')
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon['Name'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8420\661780641.py in ?()
# ----> 1 pokemon['Name'].upper()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
pokemon['Name'].index.astype(str).upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pokemon['Name'].index.astype(str).upper()
#
# AttributeError: 'Index' object has no attribute 'upper'

# %%
pokemon['Name'].str.upper()
# Out:
# #
# 1                  BULBASAUR
# 2                    IVYSAUR
# 3                   VENUSAUR
# 3      VENUSAURMEGA VENUSAUR
# 4                 CHARMANDER
#                ...
# 719                  DIANCIE
# 719      DIANCIEMEGA DIANCIE
# 720      HOOPAHOOPA CONFINED
# 720       HOOPAHOOPA UNBOUND
# 721                VOLCANION
# Name: Name, Length: 800, dtype: object

# %%
pokemon['Name'].str.lower()
# Out:
# #
# 1                  bulbasaur
# 2                    ivysaur
# 3                   venusaur
# 3      venusaurmega venusaur
# 4                 charmander
#                ...
# 719                  diancie
# 719      dianciemega diancie
# 720      hoopahoopa confined
# 720       hoopahoopa unbound
# 721                volcanion
# Name: Name, Length: 800, dtype: object

# %%
pokemon['Attack'].str.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 pokemon['Attack'].str.upper()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
pokemon['Name'].str[::-1]
# Out:
# #
# 1                  ruasabluB
# 2                    ruasyvI
# 3                   ruasuneV
# 3      ruasuneV ageMruasuneV
# 4                 rednamrahC
#                ...
# 719                  eicnaiD
# 719      eicnaiD ageMeicnaiD
# 720      denifnoC apooHapooH
# 720       dnuobnU apooHapooH
# 721                noinacloV
# Name: Name, Length: 800, dtype: object

# %%
q_mask = pokemon['Name'].str.contains('q', case=False)
pokemon[q_mask]
# Out:
#                       Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# #
# 7                 Squirtle   Water     NaN    314   44      48       65
# 31               Nidoqueen  Poison  Ground    505   90      92       87
# 155              Cyndaquil    Fire     NaN    309   39      52       43
# 156                Quilava    Fire     NaN    405   58      64       58
# 195               Quagsire   Water  Ground    430   95      85       85
# 211               Qwilfish   Water  Poison    430   65      95       75
# 284             Masquerain     Bug  Flying    414   70      60       62
# 384               Rayquaza  Dragon  Flying    680  105     150       90
# 384  RayquazaMega Rayquaza  Dragon  Flying    780  105     180      100
# 416              Vespiquen     Bug  Flying    474   70      80      102
# 520              Tranquill  Normal  Flying    358   62      77       62
# 651              Quilladin   Grass     NaN    405   61      78       95
#
# ...

# %%
start_name_filter = pokemon['Name'].str.upper().str.startswith('Do')
pokemon[start_name_filter]
# Out:
# Empty DataFrame
# Columns: [Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
end_name_filter = pokemon['Name'].str.endswith('chu')
pokemon[end_name_filter]
# Out:
#         Name    Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 25   Pikachu  Electric    NaN    320  35      55       40       50       50
# 26    Raichu  Electric    NaN    485  60      90       55       90       80
# 172    Pichu  Electric    NaN    205  20      40       15       35       35
#
#      Speed  Generation  Legendary
# #
# 25      90           1      False
# 26     110           1      False
# 172     60           2      False

# %%
pokemon['Type 1'] = pokemon['Type 1'].str.replace('Grass', 'Green', regex=False)
pokemon[pokemon['Type 1'] == 'Green']
# Out:
#                       Name Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 1                Bulbasaur  Green    Poison    318   45      49       49
# 2                  Ivysaur  Green    Poison    405   60      62       63
# 3                 Venusaur  Green    Poison    525   80      82       83
# 3    VenusaurMega Venusaur  Green    Poison    625   80     100      123
# 43                  Oddish  Green    Poison    320   45      50       55
# ..                     ...    ...       ...    ...  ...     ...      ...
# 650                Chespin  Green       NaN    313   56      61       65
# 651              Quilladin  Green       NaN    405   61      78       95
# 652             Chesnaught  Green  Fighting    530   88     107      122
# 672                 Skiddo  Green       NaN    350   66      65       48
# 673                 Gogoat  Green       NaN    531  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

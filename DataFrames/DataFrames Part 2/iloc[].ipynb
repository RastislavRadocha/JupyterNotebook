# %%
import pandas as pd

# %%
titanic = pd.read_excel('titanic3.xls', usecols=['name', 'sex', 'age', 'pclass', 'fare'])
titanic.head(10)
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
# 6       1                Andrews, Miss. Kornelia Theodosia  female  63.0000
# 7       1                           Andrews, Mr. Thomas Jr    male  39.0000
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0000
# 9       1                          Artagaveytia, Mr. Ramon    male  71.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500
# 6   77.9583
# 7    0.0000
# ...

# %%
titanic.iloc[1306] # returns a series
# Out:
# pclass                            3
# name      Zakarian, Mr. Mapriededer
# sex                            male
# age                            26.5
# fare                          7.225
# Name: 1306, dtype: object

# %%
titanic.iloc[0:6]
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500

# %%
titanic.iloc[0:6:2]
# Out:
#    pclass                                             name     sex   age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2       1                     Allison, Miss. Helen Loraine  female   2.0
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
#
#        fare
# 0  211.3375
# 2  151.5500
# 4  151.5500

# %%
titanic.iloc[[100, 200, 300]]
# Out:
#      pclass                                          name   sex   age     fare
# 100       1  Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")  male  49.0  56.9292
# 200       1                  McCaffry, Mr. Thomas Francis  male  46.0  75.2417
# 300       1                     Van der hoef, Mr. Wyckoff  male  61.0  33.5000

# %%
titanic.iloc[-3]
# Out:
# pclass                            3
# name      Zakarian, Mr. Mapriededer
# sex                            male
# age                            26.5
# fare                          7.225
# Name: 1306, dtype: object

# %%
titanic.iloc[5, 3]
# Out:
# np.float64(48.0)

# %%
titanic.head(6)
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# 5       1                              Anderson, Mr. Harry    male  48.0000
#
#        fare
# 0  211.3375
# 1  151.5500
# 2  151.5500
# 3  151.5500
# 4  151.5500
# 5   26.5500

# %%
titanic.iloc[[4,5,6],[2,3,4]]
# Out:
#       sex   age      fare
# 4  female  25.0  151.5500
# 5    male  48.0   26.5500
# 6  female  63.0   77.9583

# %%
titanic.iloc[5, [0,2,4]]
# Out:
# pclass        1
# sex        male
# fare      26.55
# Name: 5, dtype: object

# %%
titanic.iloc[[2,8], :]
# Out:
#    pclass                                           name     sex   age  \
# 2       1                   Allison, Miss. Helen Loraine  female   2.0
# 8       1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
#
#        fare
# 2  151.5500
# 8   51.4792

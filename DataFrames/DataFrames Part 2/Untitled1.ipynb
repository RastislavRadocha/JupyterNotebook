# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
titanic = pd.read_excel('titanic3.xls', index_col = 'name')
titanic
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, Allen, Miss. Elisabeth Walton to Zimmerman, Mr. Leo
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   sex        1309 non-null   object
#  3   age        1046 non-null   float64
#  4   sibsp      1309 non-null   int64
#  5   parch      1309 non-null   int64
#  6   ticket     1309 non-null   object
#  7   fare       1308 non-null   float64
#  8   cabin      295 non-null    object
#  9   embarked   1307 non-null   object
#  10  boat       486 non-null    object
#  11  body       121 non-null    float64
#  12  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 143.2+ KB

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic.sort_index(inplace=True)
titanic
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
titanic.loc[['Abbott, Mr. Rossmore Edward', 'van Billiard, Master. James William']] # returns a DataFrame
# Out:
#                                      pclass  survived   sex   age  sibsp  \
# name
# Abbott, Mr. Rossmore Edward               3         0  male  16.0      1
# van Billiard, Master. James William       3         0  male   NaN      1
#
#                                      parch     ticket   fare cabin embarked  \
# name
# Abbott, Mr. Rossmore Edward              1  C.A. 2673  20.25   NaN        S
# van Billiard, Master. James William      1   A/5. 851  14.50   NaN        S
#
#                                     boat   body            home.dest
# name
# Abbott, Mr. Rossmore Edward          NaN  190.0  East Providence, RI
# van Billiard, Master. James William  NaN    NaN                  NaN

# %%
titanic.loc['Kelly, Mr. James']
# Out:
#                   pclass  survived   sex   age  sibsp  parch  ticket    fare  \
# name
# Kelly, Mr. James       3         0  male  34.5      0      0  330911  7.8292
# Kelly, Mr. James       3         0  male  44.0      0      0  363592  8.0500
#
#                  cabin embarked boat  body home.dest
# name
# Kelly, Mr. James   NaN        Q  NaN  70.0       NaN
# Kelly, Mr. James   NaN        S  NaN   NaN       NaN

# %%
titanic.loc['Abbing, Mr. Anthony':'Abelseth, Miss. Karen Marie']
# Out:
#                                   pclass  survived     sex   age  sibsp  \
# name
# Abbing, Mr. Anthony                    3         0    male  42.0      0
# Abbott, Master. Eugene Joseph          3         0    male  13.0      0
# Abbott, Mr. Rossmore Edward            3         0    male  16.0      1
# Abbott, Mrs. Stanton (Rosa Hunt)       3         1  female  35.0      1
# Abelseth, Miss. Karen Marie            3         1  female  16.0      0
#
#                                   parch     ticket   fare cabin embarked boat  \
# name
# Abbing, Mr. Anthony                   0  C.A. 5547   7.55   NaN        S  NaN
# Abbott, Master. Eugene Joseph         2  C.A. 2673  20.25   NaN        S  NaN
# Abbott, Mr. Rossmore Edward           1  C.A. 2673  20.25   NaN        S  NaN
# Abbott, Mrs. Stanton (Rosa Hunt)      1  C.A. 2673  20.25   NaN        S    A
# Abelseth, Miss. Karen Marie           0     348125   7.65   NaN        S   16
#
# ...

# %%
titanic.head(3)
# Out:
#                                pclass  survived   sex   age  sibsp  parch  \
# name
# Abbing, Mr. Anthony                 3         0  male  42.0      0      0
# Abbott, Master. Eugene Joseph       3         0  male  13.0      0      2
# Abbott, Mr. Rossmore Edward         3         0  male  16.0      1      1
#
#                                   ticket   fare cabin embarked boat   body  \
# name
# Abbing, Mr. Anthony            C.A. 5547   7.55   NaN        S  NaN    NaN
# Abbott, Master. Eugene Joseph  C.A. 2673  20.25   NaN        S  NaN    NaN
# Abbott, Mr. Rossmore Edward    C.A. 2673  20.25   NaN        S  NaN  190.0
#
#                                          home.dest
# name
# Abbing, Mr. Anthony                            NaN
# Abbott, Master. Eugene Joseph  East Providence, RI
# Abbott, Mr. Rossmore Edward    East Providence, RI

# %%
titanic.loc['Abbing, Mr. Anthony', ['fare', 'sex', 'home.dest']]
# Out:
# fare         7.55
# sex          male
# home.dest     NaN
# Name: Abbing, Mr. Anthony, dtype: object

# %%
passengers = ['Abbott, Mr. Rossmore Edward',  'Abbott, Mrs. Stanton (Rosa Hunt)']
titanic.loc[passengers, ]
# Out:
# name
# Abbott, Mr. Rossmore Edward         20.25
# Abbott, Mrs. Stanton (Rosa Hunt)    20.25
# Name: fare, dtype: float64

# %%
columns = ['fare', 'ticket', 'body', 'pclass']
passengers = ['Abbott, Mr. Rossmore Edward',  'Abbott, Mrs. Stanton (Rosa Hunt)', 'van Billiard, Master. James William']
titanic.loc[passengers, columns]
# Out:
#                                       fare     ticket   body  pclass
# name
# Abbott, Mr. Rossmore Edward          20.25  C.A. 2673  190.0       3
# Abbott, Mrs. Stanton (Rosa Hunt)     20.25  C.A. 2673    NaN       3
# van Billiard, Master. James William  14.50   A/5. 851    NaN       3
